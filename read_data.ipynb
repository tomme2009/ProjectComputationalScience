# %%
import pandas as pd
import numpy as np

# %%
parties = ['GL', 'PvdA', 'SP', 'PvdD', 'VN', 'DENK', 'CU', 'VVD', 'D66', '50+', 'FvD', 'JA21', 'PVV', 'BBB', 'SGP']
df = pd.read_csv('view_party.csv').loc[lambda df: df['country_name'] == 'Netherlands']
df
# Out:
#      country_name_short country_name party_name_short  \
# 1294                NLD  Netherlands              50+
# 1295                NLD  Netherlands          AOV|VSP
# 1296                NLD  Netherlands              ARP
# 1297                NLD  Netherlands              BBB
# 1298                NLD  Netherlands              BVL
# 1299                NLD  Netherlands               Bp
# 1300                NLD  Netherlands               CD
# 1301                NLD  Netherlands              CDA
# 1302                NLD  Netherlands              CDU
# 1303                NLD  Netherlands              CHU
# 1304                NLD  Netherlands               CP
# 1305                NLD  Netherlands              CPN
# 1306                NLD  Netherlands               CU
# 1307                NLD  Netherlands              D66
# 1308                NLD  Netherlands             DENK
# 1309                NLD  Netherlands             DS70
# ...

# %%
for party in parties:
    print('Party', party, ':', np.asarray(df.loc[lambda df: df['party_name_short'] == party]['left_right'])[0])
# Out:
# Party GL : 2.0454
# Party PvdA : 3.6118
# Party SP : 1.3682
# Party PvdD : nan
# Party VN : nan
# Party DENK : 3.3
# Party CU : 6.1732
# Party VVD : 7.3482
# Party D66 : 4.5066
# Party 50+ : nan
# Party FvD : 8.7
# Party JA21 : 8.7
# Party PVV : 8.8
# Party BBB : 5.3
# Party SGP : 8.7531
